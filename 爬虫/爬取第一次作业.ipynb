# %%
import os
os.getcwd()
os.chdir("G://CDO//数据存储和获取//第二次")

# %%
import requests

# %%
res = requests.get('https://taobao.com')

# %%
print(res.status_code)
# Out:
# 200

# %%
print(res.text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#       <!DOCTYPE HTML>
# <html >
# 	<head>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta name="keywords" content="淘宝,淘寶,淘寶網,掏寶,掏保,網上購物,集運,淘宝全球,taobao" />
# <meta name="description" content="您可以在淘寶網快速搜索女裝、男裝、鞋包、飾品、運動、家居家紡、手機数位、家電、美妝等各品類優質商品，並通過支付寶享受安全的擔保交易服務（先收貨後確認），以優惠的價格將多件商品一併集運，幫您大大節省物流開支，現時已覆蓋香港、澳門、臺灣、新加坡、馬來西亞、美國、加拿大、澳大利亞、紐西蘭和日本等地區。" />
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta charset="utf-8"/>
# <meta name="renderer" content="webkit"/>
# <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
# <link rel="dns-prefetch" href="//g.alicdn.com"/>
# <link rel="dns-prefetch" href="//img.alicdn.com"/>
# <link rel="dns-prefetch" href="//bar.tmall.com"/>
# <link rel="dns-prefetch" href="//ts.tmall.com"/>
# <link rel="dns-prefetch" href="//h5api.m.tmall.com"/>
# <link rel="dns-prefetch" href="//log.mmstat.com"/>
# <link href="//img.alicdn.com/tfs/TB1VlKFRpXXXXcNapXXXXXXXXXX-16-16.png" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
print(res.cookies)
# Out:
# <RequestsCookieJar[]>

# %%
r =  requests.get('https://movie.douban.com/')

# %%
print(r.status_code)
# Out:
# 418

# %%
print(r.text)

# %%
print(r.cookies)
# Out:
# <RequestsCookieJar[]>

# %%
re=requests.get('http://www.wdzxx.com/uploadfile/2017/0921/20170921021432102.jpg')
print(re.status_code)
print(re.content)
# Out:
# 200
# ...

# %%
with open('G://CDO/数据存储和获取//第二次//20170921021432102.jpg','wb') as f:
      f.write(re.content)
