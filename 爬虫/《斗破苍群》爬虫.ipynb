# %%
import requests
import time
import os
os.getcwd()
os.chdir("F:/异类语言/读书/")
import requests
import re
import pandas as pd
import json

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Mobile Safari/537.36'}
url = "http://www.doupoxs.com/doupocangqiong/"
web =requests.get(url, headers = headers)

web.status_code

web_text = web.text
web_text
print(web.status_code)
print(web_text)
# Out:
# 200
# <!doctype html>
# <html lang="zh-CN">
# <head>
# <meta charset="utf-8">
# <title>æç ´èç©¹å°è¯´å¨æåè´¹å¨çº¿éè¯»(å¤©èåè±) - æç ´å°è¯´ç½</title>
# <meta name="description" content="æç ´å°è¯´ç½å¨ç«æ å¼¹çª,å°è¯´åè´¹å¨çº¿éè¯»,æç ´èç©¹å°è¯´ç« èç±ç½åæä¾,ä½èå¤©èåè±,æä¾æç ´èç©¹å°è¯´å¨æåè´¹éè¯»,æç ´èç©¹å¨çº¿éè¯»ä¸æ å¼¹çª,åè´¹æä¾æç ´èç©¹ç¬è¶£éå¨ææ¸ç½å¹²åçæå­ç« èå¨çº¿éè¯»ã" />
# <meta name="keywords" content="æç ´èç©¹å°è¯´">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <meta name="applicable-device" content="pc,mobile">
# <meta name="renderer" content="webkit">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1" />
# <meta http-equiv="Cache-Control" content="no-transform " />
# <meta http-equiv="Cache-Control" content="no-siteapp" />
# <!--å¿å¡«-->
# <meta property="og:type" content="novel"/>
# <meta property="og:title" content="æç ´èç©¹"/>
# ...

# %%
web.content
# Out:
# b'<!doctype html>\r\n<html lang="zh-CN">\r\n<head>\r\n<meta charset="utf-8">  \r\n<title>\xe6\x96\x97\xe7\xa0\xb4\xe8\x8b\x8d\xe7\xa9\xb9\xe5\xb0\x8f\xe8\xaf\xb4\xe5\x85\xa8\xe6\x96\x87\xe5\x85\x8d\xe8\xb4\xb9\xe5\x9c\xa8\xe7\xba\xbf\xe9\x98\x85\xe8\xaf\xbb(\xe5\xa4\xa9\xe8\x9a\x95\xe5\x9c\x9f\xe8\xb1\x86) - \xe6\x96\x97\xe7\xa0\xb4\xe5\xb0\x8f\xe8\xaf\xb4\xe7\xbd\x91</title>\r\n<meta name="description" content="\xe6\x96\x97\xe7\xa0\xb4\xe5\xb0\x8f\xe8\xaf\xb4\xe7\xbd\x91\xe5\x85\xa8\xe7\xab\x99\xe6\x97\xa0\xe5\xbc\xb9\xe7\xaa\x97,\xe5\xb0\x8f\xe8\xaf\xb4\xe5\x85\x8d\xe8\xb4\xb9\xe5\x9c\xa8\xe7\xba\xbf\xe9\x98\x85\xe8\xaf\xbb,\xe6\x96\x97\xe7\xa0\xb4\xe8\x8b\x8d\xe7\xa9\xb9\xe5\xb0\x8f\xe8\xaf\xb4\xe7\xab\xa0\xe8\x8a\x82\xe7\x94\xb1\xe7\xbd\x91\xe5\x8f\x8b\xe6\x8f\x90\xe4\xbe\x9b,\xe4\xbd\x9c\xe8\x80\x85\xe5\xa4\xa9\xe8\x9a\x95\xe5\x9c\x9f\xe8\xb1\x86,\xe6\x8f\x90\xe4\xbe\x9b\xe6\x96\x97\xe7\xa0\xb4\xe8\x8b\x8d\xe7\xa9\xb9\xe5\xb0\x8f\xe8\xaf\xb4\xe5\x85\xa8\xe6\x96\x87\xe5\x85\x8d\x
# ...

# %%
for url in url:
    urls = ['http://www.doupoxs.com/doupocangqiong/{}.html'.format(str(i)) for i in range(2,1665)]      
    headers={'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Mobile Safari/537.36'}
    res=requests.get(urls,headers=headers)
    contents = re.compile('<p>(.*?)</p>',re.S)
    items=re.findall(contents,web_text)
    for item in items:
        dict={}
        with open('F:/异类语言/读书/斗破苍穹.TXT','a',encoding='utf-8')as f:
            f.write(json.dumps(dict,ensure_ascii=False)+'\n')
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-19-7d684b7994c8> in <module>
#       2     urls = ['http://www.doupoxs.com/doupocangqiong/{}.html'.format(str(i)) for i in range(2,1665)]
#       3     headers={'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Mobile Safari/537.36'}
# ----> 4     res=requests.get(urls,headers=headers)
#       5     contents = re.compile('<p>(.*?)</p>',re.S)
#       6     items=re.findall(contents,web_text)
#
# ~\AppData\Roaming\Python\Python37\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\AppData\Roaming\Python\Python37\site-packages\requests\api.py in request(method, url, **kwargs)
# ...
