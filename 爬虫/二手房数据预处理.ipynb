# %%
import pandas as pd
fang = pd.read_csv("F://异类语言//python//ljlpython//第七次作业//西安二手房新.csv",sep=",",encoding = 'gbk')
fang.head()
# Out:
#                               介绍   总价（元）   房屋信息房屋编码        发布时间          小区  \
# 0         两梯两户纯板风景御园可按揭地铁2号线公园旁边   260.0  649844308   2016/11/6      保亿风景御园
# 1          精装三居全配拎包入住婚房出售仅此一套60万    60.0  657563575  2016/11/14        世融嘉城
# 2        境商速递曲江公馆和园南湖边别墅品牌地产位置优越  1340.0  652092703   2016/11/8  曲江公馆和园（别墅）
# 3  科技六路万达旁兰亭坊二期5室2厅3卫256豪华装修,带私立   529.0  656304305  2016/11/13         兰亭坊
# 4       高山流水婚房出售拎包入住仅120万可按揭玛雅新推   120.0  657972394  2016/11/15    高山流水幸福快车
#
#    城区     地址                位置    年代  房龄  卧室数  厅数  生间    总面积  朝向  楼层    楼高  \
# 0  城北    经开区  城市运动公园南侧，张家堡转盘西侧  2000  17    3   2   2  188.0  南北  中层  共28层
# 1  城北    经开区      凤城四路与朱宏路十字东南  2012   5    2   2   1  102.0   南  中层  共32层
# 2  曲江   曲江新区          芙蓉西路雁塔一路  2015   2    5   2   3  452.0  南北  其他   共3层
# 3  高新  木塔寺公园            科技六路中段  2011   6    5   2   3  256.0  南北  高层  共16层
# 4  城北    经开区          太华北路848号  2010   7    4   2   2  139.0   南  低层  共30层
#
#      装修     单价     中介公司名称
# 0  简单装修  13829       亿德地产
# ...

# %%
fang.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2907    False
# 2908    False
# 2909    False
# 2910    False
# 2911    False
# Length: 2912, dtype: bool

# %%
q=fang.drop_duplicates()
q.head()
# Out:
#                               介绍   总价（元）   房屋信息房屋编码        发布时间          小区  \
# 0         两梯两户纯板风景御园可按揭地铁2号线公园旁边   260.0  649844308   2016/11/6      保亿风景御园
# 1          精装三居全配拎包入住婚房出售仅此一套60万    60.0  657563575  2016/11/14        世融嘉城
# 2        境商速递曲江公馆和园南湖边别墅品牌地产位置优越  1340.0  652092703   2016/11/8  曲江公馆和园（别墅）
# 3  科技六路万达旁兰亭坊二期5室2厅3卫256豪华装修,带私立   529.0  656304305  2016/11/13         兰亭坊
# 4       高山流水婚房出售拎包入住仅120万可按揭玛雅新推   120.0  657972394  2016/11/15    高山流水幸福快车
#
#    城区     地址                位置    年代  房龄  卧室数  厅数  生间    总面积  朝向  楼层    楼高  \
# 0  城北    经开区  城市运动公园南侧，张家堡转盘西侧  2000  17    3   2   2  188.0  南北  中层  共28层
# 1  城北    经开区      凤城四路与朱宏路十字东南  2012   5    2   2   1  102.0   南  中层  共32层
# 2  曲江   曲江新区          芙蓉西路雁塔一路  2015   2    5   2   3  452.0  南北  其他   共3层
# 3  高新  木塔寺公园            科技六路中段  2011   6    5   2   3  256.0  南北  高层  共16层
# 4  城北    经开区          太华北路848号  2010   7    4   2   2  139.0   南  低层  共30层
#
#      装修     单价     中介公司名称
# 0  简单装修  13829       亿德地产
# ...

# %%
fang.朝向.value_counts()
# Out:
# 南北    1713
# 南      560
# 东南     211
# 西南     121
# 北       80
# 东       78
# 东北      50
# 西北      45
# 西       39
# 东西      15
# Name: 朝向, dtype: int64

# %%
fang.装修.value_counts()
# Out:
# 精装修     1154
# 毛坯       955
# 中等装修     379
# 简单装修     253
# 豪华装修     171
# Name: 装修, dtype: int64

# %%
fang.iloc[:,0:4].apply(np.mean,axis=0)
# Out:
#   File "<ipython-input-130-1463587ee795>", line 1
#     fang.iloc[[:,0:6]].apply(np.mean,axis=0)
#                ^
# SyntaxError: invalid syntax

# %%
fang.城区.value_counts()
# Out:
# 城北    779
# 高新    609
# 曲江    473
# 城东    290
# 城南    270
# 长安    233
# 城西    143
# 浐灞    109
# 其他      6
# Name: 城区, dtype: int64

# %%
groupby_m=fang.groupby(['城区']).aggregate(np.mean)
groupby_m
# Out:
#          总价（元）      房屋信息房屋编码           年代        房龄       卧室数        厅数  \
# 城区
# 其他   86.833333  6.419013e+08  2007.666667  9.333333  2.833333  1.666667
# 城东   70.607241  6.456466e+08  2009.789655  7.210345  2.493103  1.917241
# 城北   77.802953  6.462515e+08  2011.200257  5.799743  2.576380  1.912709
# 城南   78.088889  6.450588e+08  2008.611111  8.388889  2.451852  1.711111
# 城西   82.551049  6.469421e+08  2009.258741  7.741259  2.615385  1.867133
# 曲江  284.748414  6.466694e+08  2012.972516  4.027484  3.469345  2.126850
# 浐灞  146.686239  6.484376e+08  2012.944954  4.055046  2.807339  2.027523
# 长安   73.108155  6.435153e+08  2011.901288  5.098712  2.626609  1.939914
# 高新  119.833169  6.470492e+08  2009.773399  7.226601  2.761905  1.903120
#
#           生间         总面积            单价
# 城区
# 其他  1.833333  124.966667   6915.666667
# 城东  1.393103  108.240345   6259.051724
# 城北  1.477535  110.792426   6631.572529
# 城南  1.351852  104.831111   7409.192593
# ...

# %%
groupby_fang=fang.groupby([fang.城区,fang.装修]).aggregate(np.mean)
groupby_fang
# Out:
#               总价（元）      房屋信息房屋编码           年代         房龄       卧室数        厅数  \
# 城区 装修
# 其他 毛坯     36.000000  6.229782e+08  2015.000000   2.000000  3.000000  2.000000
#    简单装修  102.500000  6.421959e+08  2006.500000  10.500000  3.000000  2.000000
#    精装修    67.500000  6.496915e+08  2008.000000   9.000000  2.000000  1.000000
#    豪华装修  145.000000  6.446547e+08  2002.000000  15.000000  4.000000  2.000000
# 城东 中等装修   65.818182  6.482138e+08  2007.863636   9.136364  2.303030  1.939394
#    毛坯     65.309615  6.439827e+08  2013.961538   3.038462  2.500000  1.980769
#    简单装修   55.410714  6.463857e+08  2007.642857   9.357143  2.321429  1.714286
#    精装修    73.925000  6.449674e+08  2009.542857   7.457143  2.592857  1.914286
#    豪华装修  208.750000  6.435186e+08  2011.000000   6.000000  3.250000  2.250000
# 城北 中等装修   65.825180  6.473196e+08  2008.971223   8.028777  2.338129  1.856115
#    毛坯     63.408171  6.456925e+08  2013.789883   3.210117  2.618677  1.976654
# ...

# %%
fang.groupby([fang.城区,fang.装修]).mean()
# Out:
#               总价（元）      房屋信息房屋编码           年代         房龄       卧室数        厅数  \
# 城区 装修
# 其他 毛坯     36.000000  6.229782e+08  2015.000000   2.000000  3.000000  2.000000
#    简单装修  102.500000  6.421959e+08  2006.500000  10.500000  3.000000  2.000000
#    精装修    67.500000  6.496915e+08  2008.000000   9.000000  2.000000  1.000000
#    豪华装修  145.000000  6.446547e+08  2002.000000  15.000000  4.000000  2.000000
# 城东 中等装修   65.818182  6.482138e+08  2007.863636   9.136364  2.303030  1.939394
#    毛坯     65.309615  6.439827e+08  2013.961538   3.038462  2.500000  1.980769
#    简单装修   55.410714  6.463857e+08  2007.642857   9.357143  2.321429  1.714286
#    精装修    73.925000  6.449674e+08  2009.542857   7.457143  2.592857  1.914286
#    豪华装修  208.750000  6.435186e+08  2011.000000   6.000000  3.250000  2.250000
# 城北 中等装修   65.825180  6.473196e+08  2008.971223   8.028777  2.338129  1.856115
#    毛坯     63.408171  6.456925e+08  2013.789883   3.210117  2.618677  1.976654
# ...

# %%
pd.crosstab(fang.朝向,fang.楼层)
# Out:
# 楼层   中层   低层  其他   高层
# 朝向
# 东    31   19   0   28
# 东北   16    8   1   25
# 东南   92   48   0   71
# 东西    5    3   2    5
# 北    27   25   0   28
# 南   262  146   8  144
# 南北  731  401  57  524
# 西    14    9   0   16
# 西北   18   14   0   13
# 西南   47   27   0   47

# %%
fang.iloc[:,'城区'].apply(np.mean,axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# E:\anaconda\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     234             try:
# --> 235                 self._validate_key(k, i)
#     236             except ValueError:
#
# E:\anaconda\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    2034                 "Can only index by location with "
# -> 2035                 "a [{types}]".format(types=self._valid_types)
#    2036             )
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-e056e3639147> in <module>
# ...
