# %%
import requests
import re
import time
from multiprocessing import Pool
from bs4 import BeautifulSoup
import json
from lxml import etree

# %%
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36'}

# %%
url1 = 'https://www.jianshu.com/c/bDHhpK?order_by=added_at&page=1'

# %%
resp = requests.get(url1, headers=headers)
html_content1 = resp.text 
soup = BeautifulSoup(html_content1, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 6]><html class="ie lt-ie8"><![endif]--><!--[if IE 7]><html class="ie lt-ie8"><![endif]--><!--[if IE 8]><html class="ie ie8"><![endif]--><!--[if IE 9]><html class="ie ie9"><![endif]--><!--[if !IE]><!--><html> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0,user-scalable=no" name="viewport"/>
# <!-- Start of Baidu Transcode -->
# <meta content="no-siteapp" http-equiv="Cache-Control"/>
# <meta content="no-transform" http-equiv="Cache-Control"/>
# <meta content="pc,mobile" name="applicable-device"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="format=html5;url=https://www.jianshu.com/c/bDHhpK?order_by=added_at&amp;page=1" name="mobile-agent"/>
# <!-- End of Baidu Transcode -->
# <meta content="原首页投稿专题
#
# 现暂停使用。
#
# ...

# %%
ss=soup.find_all('div')
ss
# Out:
# [<div class="width-limit">
#  <!-- 左上方 Logo -->
#  <a class="logo" href="/"><img alt="Nav logo" src="//cdn2.jianshu.io/assets/web/nav-logo-4c7bbafe27adc892f3046e6978459bac.png"/></a>
#  <!-- 右上角 -->
#  <!-- 未登录显示登录/注册/写文章 -->
#  <a class="btn write-btn" href="/writer#/" target="_blank">
#  <i class="iconfont ic-write"></i>写文章
#  </a> <a class="btn sign-up" href="/sign_up" id="sign_up">注册</a>
#  <a class="btn log-in" href="/sign_in" id="sign_in">登录</a>
#  <!-- 如果用户登录，显示下拉菜单 -->
#  <div id="navbar-jsds-enter">
#  </div>
#  <div id="view-mode-ctrl">
#  </div>
#  <div class="container">
#  <div class="navbar-header">
#  <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#menu" data-toggle="collapse" type="button">
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  </button>
#  </div>
#  <div class="collapse navbar-collapse" id="menu">
#  <ul class="nav navbar-nav">
#  <li class="tab">
#  <a href="/">
# ...

# %%
html1 = etree.HTML(html_content1)
html1
# Out:
# <Element html at 0x136343f8b88>

# %%
infos = html1.xpath('//ul[@class="note-list"]/li')
infos
# Out:
# [<Element li at 0x13634404208>,
#  <Element li at 0x13634409208>,
#  <Element li at 0x13634409248>,
#  <Element li at 0x13634409288>,
#  <Element li at 0x136344092c8>,
#  <Element li at 0x13634409348>,
#  <Element li at 0x13634409388>,
#  <Element li at 0x136344093c8>,
#  <Element li at 0x13634409408>,
#  <Element li at 0x13634409308>]

# %%
n1 = soup.find_all(name='a',class_='nickname')
n1
# Out:
# [<a class="nickname" href="/u/1d467fec18db" target="_blank">铃铛子</a>,
#  <a class="nickname" href="/u/dc22650a4033" target="_blank">一鸣</a>,
#  <a class="nickname" href="/u/94114ad800cf" target="_blank">浅笑微印Natasha</a>,
#  <a class="nickname" href="/u/854cb566c478" target="_blank">灰土豆</a>,
#  <a class="nickname" href="/u/e9476f6e5ec0" target="_blank">shux33</a>,
#  <a class="nickname" href="/u/62eb2baf2c62" target="_blank">lostdays</a>,
#  <a class="nickname" href="/u/f666aefcc318" target="_blank">晖宗聊绘画</a>,
#  <a class="nickname" href="/u/854cb566c478" target="_blank">灰土豆</a>,
#  <a class="nickname" href="/u/854cb566c478" target="_blank">灰土豆</a>,
#  <a class="nickname" href="/u/a8dbb73c03ab" target="_blank">太湖浪子</a>]

# %%
title=html1.xpath('//div//a[@class="title"]//text()')
title
# Out:
# ['普通人可以快速高效掌握的手绘手账书来啦！',
#  '一套写小说的功夫',
#  '燕南飞，千里文缘一线牵',
#  '电影的光 | 资料馆记事（13）',
#  '【复盘】腾讯暑期实习产品运营群面',
#  '列车',
#  '那年的诗与心中的远方',
#  '未来奇谭 |《鬼影奇情录》（3）',
#  '未来奇谭 |《鬼影奇情录》（2）',
#  '（言情•成长）千娇百媚3']

# %%
abstract=html1.xpath('//li//p[@class="abstract"]//text()')
abstract
# Out:
# ['\n      一 历时1年半的打磨与生产，铃铛子的《21天简笔画萌萌哒手账训练营》和大家面基啦！ 这两年越来越多的人想学手绘，却不知道从哪里开始学，想要靠自己...\n    ',
#  '\n      一位作家这样总结写作者的三个阶段，第一阶段是自我表达期，第二阶段是刻意训练期，第三阶段是风格成熟期。 简单来说，第一阶段专注于个人世界的表达，写...\n    ',
#  '\n      2018年4月16日   星期一   天气 晴 四月，春意盎然，莺歌蝶舞，美丽的燕子南飞，在江南的土地上生息繁衍。而有一名特殊的客人，他就像燕子...\n    ',
#  '\n      这一系列文章是2010年—2013年在中国电影艺术研究中心（中国电影资料馆）念研究生期间写作的，以记录资料馆的电影学习与生活。电影的光如何渗进我...\n    ',
#  '\n      题目：无人岛的开发与推广商业计划书 什么是“无人岛”？ 无人岛并非没人居住，而是未列入编制的海岛； 无人岛开发失败原因之一，是对开发的困难估计不...\n    ',
#  '\n      “你在干嘛。” “写东西。” “你写东西干嘛。” “为了不和你说话也不尴尬。” “你和我说话不就不尴尬了，”他一把扳过我笔记本的屏幕：“列车？这...\n    ',
#  '\n      上大学的时候，有段时间很喜欢苏轼的词，但坦白的说，我并不喜欢他的人，他与王安石比起来，我觉得少了点实干精神。 “人生到处知何似，应似飞鸿踏雪泥”...\n    ',
#  '\n      六   舞台上火熊熊燃烧起来，把师徒四人紧紧围住了。这时候，穿着孙悟空戏服的滑板少年尽管明白自己是在一部电影里，却又真切地感受到了灼烧带来的疼痛...\n    ',
#  '\n      三   在电影诞生两百年的这个世纪末，影院数量在不断下降。人们有了一些新的观影体验，比如裸眼3D电影，或者有了一些新的互动方式，比如观众按下座位...\n    ',
#  '\n      并蒂莲花争艳丽，防火防盗防闺蜜。 初恋福兮抑或祸，成长道路坎坷多。 人在江湖不由己，千娇百媚各显灵。 山转水覆疑无路，殊途同归皆欢喜。 早恋这种...\n    ']

# %%
id=html1.xpath('//div//i//@data-note-id')
id
# Out:
# ['27868381',
#  '27766499',
#  '26735246',
#  '26742262',
#  '26675089',
#  '26734267',
#  '26720649',
#  '26714571',
#  '26714336',
#  '26660928']

# %%
title = html1.xpath('.//div/a/text()')
title
# Out:
# ['\n        ',
#  '写文章\n',
#  '注册',
#  '登录',
#  '\n          ',
#  '\n',
#  '投稿',
#  '首页投稿（暂停使用，暂停投稿）',
#  '普通人可以快速高效掌握的手绘手账书来啦！',
#  '铃铛子',
#  '\n          ',
#  ' 40\n',
#  '一套写小说的功夫',
#  '一鸣',
#  '\n          ',
#  ' 168\n',
#  '燕南飞，千里文缘一线牵',
#  '浅笑微印Natasha',
#  '\n          ',
#  ' 96\n',
#  '电影的光 | 资料馆记事（13）',
#  '灰土豆',
#  '\n          ',
#  ' 0\n',
#  '【复盘】腾讯暑期实习产品运营群面',
#  'shux33',
#  '\n          ',
#  ' 0\n',
#  '列车',
#  'lostdays',
#  '\n          ',
#  ' 38\n',
#  '那年的诗与心中的远方',
#  '晖宗聊绘画',
#  '\n          ',
#  ' 4\n',
#  '未来奇谭 |《鬼影奇情录》（3）',
#  '灰土豆',
#  '\n          ',
#  ' 0\n',
#  '未来奇谭 |《鬼影奇情录》（2）',
#  '灰土豆',
#  '\n          ',
#  ' 0\n',
#  '（言情•成长）千娇百媚3',
#  '太湖浪子',
#  '\n          ',
#  ' 114\n']

# %%
t1 = html1.xpath('.//div/p/text()')
t1
# Out:
# ['\n      一 历时1年半的打磨与生产，铃铛子的《21天简笔画萌萌哒手账训练营》和大家面基啦！ 这两年越来越多的人想学手绘，却不知道从哪里开始学，想要靠自己...\n    ',
#  '\n      一位作家这样总结写作者的三个阶段，第一阶段是自我表达期，第二阶段是刻意训练期，第三阶段是风格成熟期。 简单来说，第一阶段专注于个人世界的表达，写...\n    ',
#  '\n      2018年4月16日   星期一   天气 晴 四月，春意盎然，莺歌蝶舞，美丽的燕子南飞，在江南的土地上生息繁衍。而有一名特殊的客人，他就像燕子...\n    ',
#  '\n      这一系列文章是2010年—2013年在中国电影艺术研究中心（中国电影资料馆）念研究生期间写作的，以记录资料馆的电影学习与生活。电影的光如何渗进我...\n    ',
#  '\n      题目：无人岛的开发与推广商业计划书 什么是“无人岛”？ 无人岛并非没人居住，而是未列入编制的海岛； 无人岛开发失败原因之一，是对开发的困难估计不...\n    ',
#  '\n      “你在干嘛。” “写东西。” “你写东西干嘛。” “为了不和你说话也不尴尬。” “你和我说话不就不尴尬了，”他一把扳过我笔记本的屏幕：“列车？这...\n    ',
#  '\n      上大学的时候，有段时间很喜欢苏轼的词，但坦白的说，我并不喜欢他的人，他与王安石比起来，我觉得少了点实干精神。 “人生到处知何似，应似飞鸿踏雪泥”...\n    ',
#  '\n      六   舞台上火熊熊燃烧起来，把师徒四人紧紧围住了。这时候，穿着孙悟空戏服的滑板少年尽管明白自己是在一部电影里，却又真切地感受到了灼烧带来的疼痛...\n    ',
#  '\n      三   在电影诞生两百年的这个世纪末，影院数量在不断下降。人们有了一些新的观影体验，比如裸眼3D电影，或者有了一些新的互动方式，比如观众按下座位...\n    ',
#  '\n      并蒂莲花争艳丽，防火防盗防闺蜜。 初恋福兮抑或祸，成长道路坎坷多。 人在江湖不由己，千娇百媚各显灵。 山转水覆疑无路，殊途同归皆欢喜。 早恋这种...\n    ',
#  '专题公告',
#  '原首页投稿专题',
#  '现暂停使用。',
# ...

# %%
t2 = html1.xpath('.//div/div/span[1]/text()')
t2
# Out:
# ['\n          ',
#  ' 8.1\n        ',
#  '\n          ',
#  ' 71.8\n        ',
#  '\n          ',
#  ' 0.1\n        ',
#  '\n          ',
#  ' 0.3\n        ',
#  '\n          ',
#  ' 0.1\n        ',
#  '\n          ',
#  ' 0.6\n        ',
#  '\n          ',
#  ' 3.5\n        ',
#  ' 6',
#  ' 4',
#  ' 93',
#  '分享到']

# %%
t3 = html1.xpath('.//div/div/a[1]/text()')
t3
# Out:
# ['\n          ',
#  '\n',
#  '首页投稿（暂停使用，暂停投稿）',
#  '铃铛子',
#  '一鸣',
#  '浅笑微印Natasha',
#  '灰土豆',
#  'shux33',
#  'lostdays',
#  '晖宗聊绘画',
#  '灰土豆',
#  '灰土豆',
#  '太湖浪子']

# %%
t4 = html1.xpath('.//div/div/a[2]/text()')
t4
# Out:
# ['投稿',
#  '\n          ',
#  ' 41\n',
#  '\n          ',
#  ' 168\n',
#  '\n          ',
#  ' 96\n',
#  '\n          ',
#  ' 0\n',
#  '\n          ',
#  ' 0\n',
#  '\n          ',
#  ' 38\n',
#  '\n          ',
#  ' 4\n',
#  '\n          ',
#  ' 0\n',
#  '\n          ',
#  ' 0\n',
#  '\n          ',
#  ' 114\n']

# %%
t5 = html1.xpath('.//div/div/span[2]/text()')
t5
# Out:
# [' 223', ' 1256', ' 73', ' 6', ' 7', ' 32', ' 29']

# %%
import pandas as pd
columns={'名称':title,'评论':t1,'星级':t2,'昵称':t3,'评论数':t4,'点赞数':t5}
data=pd.DataFrame(columns)  
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-938e54af1893> in <module>
#       1 import pandas as pd
#       2 columns={'名称':title,'评论':t1,'星级':t2,'昵称':t3,'评论数':t4,'点赞数':t5}
# ----> 3 data=pd.DataFrame(columns)
#       4 data.head()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# ...

# %%
with open(r"G:\CDO\数据存储和获取\articles.txt","w") as file:   
    for title in titles:  
        file.write(title.string+'\n')  
        file.write("http://www.jianshu.com" + title.get('href')+'\n\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-54ee6a724cec> in <module>
# ----> 1 dat['nickname']
#
# TypeError: list indices must be integers or slices, not str

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36\
(KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}

# %%
def getInfo(url):
    r = requests.get(url, headers=headers)
    selector = etree.HTML(r.text)
    infos = selector.xpath('//ul[@class="note-list"]/li')
    for info in infos:
        try:
            author = info.xpath('div/div/a/text()')[0]#作者
            title = info.xpath('div/a/text()')[0]#标题
            content = info.xpath('div/p/text()')[0]#内容
            comment = info.xpath('div/div/a[2]/text()')[1].strip()#评论数
            like = info.xpath('div/div/span[1]/text()')[0]#点赞数
            rewards = info.xpath('div/div/span[2]/text()')#打赏数
            if len(rewards) == 0:
                reward = '无'
            else:
                reward = rewards[0].strip()
            data = {
                'author':author,
                'title':title,
                'content':content,
                'comment':comment,
                'like':like,
                'reward':reward,
                }
        except IndexError:
            pass

# %%
if __name__ == '__main__':
    urls = ['https://www.jianshu.com/c/bDHhpK?order_by=top&page={}'.\
            format(str(i)) for i in range(1,5)]
    pool = Pool(processes=2)
    pool.map(getInfo, urls)
    pool.close()
    pool.join()
