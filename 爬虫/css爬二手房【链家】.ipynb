# %%
import os
os.getcwd()
os.chdir("G:/CDO/数据存储和获取/")
import requests
import re
import xlwt
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://xa.lianjia.com/ershoufang/pg1rs%E8%A5%BF%E5%AE%89/"
headers = {'User-Agent':"Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Mobile Safari/537.36"}
web =requests.get(url, headers = headers)
web.status_code
web_text = web.text
print(web_text)
# Out:
# <!doctype html>
#     <html lang="en">
#       <head>
#         <meta charset="UTF-8">
# <meta name="apple-mobile-web-app-title" content="贝壳找房">
# <meta name="apple-mobile-web-app-capable" content="yes">
# <meta name="apple-mobile-web-app-status-bar-style" content="black">
# <meta name="format-detection" content="telephone=no">
# <meta name="viewport" content="initial-scale=1, maximum-scale=1, minimum-scale=1, user-scalable=no">
# <meta name="layoutmode" content="fitscreen" />
# <meta name="applicable-device" content="mobile">
# <meta http-equiv="cleartype" content="on">
# <meta http-equiv="Cache-Control" content="no-transform ">
# <meta http-equiv="X-UA-Compatible" content="ie=edge"><link rel="canonical" href="https://xa.lianjia.com/ershoufang/pg1rs%E8%A5%BF%E5%AE%89/">
#     <meta name="location" content="province=陕西;city=西安;coord=108.949074,34.26539">
#     <title>西安西安二手房房源_西安西安二手房出售|买卖|交易信息(西安链家)</title>
# ...

# %%
soup = BeautifulSoup(web_text, "html")

print(soup)  
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="贝壳找房" name="apple-mobile-web-app-title"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="initial-scale=1, maximum-scale=1, minimum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="fitscreen" name="layoutmode"/>
# <meta content="mobile" name="applicable-device"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="no-transform " http-equiv="Cache-Control"/>
# <meta content="ie=edge" http-equiv="X-UA-Compatible"/><link href="https://xa.lianjia.com/ershoufang/pg1rs%E8%A5%BF%E5%AE%89/" rel="canonical"/>
# <meta content="province=陕西;city=西安;coord=108.949074,34.26539" name="location"/>
# <title>西安西安二手房房源_西安西安二手房出售|买卖|交易信息(西安链家)</title>
# ...

# %%
ss=soup.find_all('div')
ss
# Out:
# [<div id="root"><div class="main-page ershoufang-page"><header class="kem__header"><div class="header-left"><span class="icon-back"></span><a class="switch-city" href="/city/">西安</a></div><a class="header-center" href="/xa/"><span class="logo">贝壳找房</span></a><a class="header-right icon-user" href="/my/index/"><i class="icon_user"></i></a></header><div class="lj-track" data-action='{"source_type":"M小区列表页搜索框点击"}' data-click-event="mElementClick" data-click-evtid="12477"><a class="search-input" href="/xa/ershoufang/search/">西安</a></div><div class="container"><div class="filter-bar"><div class="ershoufang-page__filter-tab"><div><div></div><div class="tab-container"><div class="kem__tab-bar"><ul class="tab-arrow"><li class="tab-item">区域</li><li class="tab-item">价格</li><li class="tab-item">房型</li><li class="tab-item">更多</li><li class="tab-item">排序</li></ul></div></div></div><div class="panel-container"><div class="conch-ui-filter-region hide conch-ui-lianjia"><div class="conch-ui-filter-li
# ...

# %%
[i.string for i in soup.select('.house-desc')]
# Out:
# ['2室1厅/70.01m²/南/万科金域东郡',
#  '3室2厅/110.38m²/南 北/西安航天城A区',
#  '3室1厅/99.6m²/南 北/华清学府城',
#  '3室1厅/149.14m²/南 北/水岸东方2期',
#  '1室1厅/53.86m²/西/宫园壹号一期',
#  '3室1厅/105.93m²/南/金科天籁城',
#  '3室2厅/95.76m²/西南/融创天朗臻园',
#  '2室1厅/88.54m²/南/绿地曲江名城',
#  '1室1厅/46.33m²/西/航天小区',
#  '3室2厅/129.13m²/南 北/枫林绿洲',
#  '1室1厅/35m²/南/逸翠园二期i都会',
#  '3室2厅/130.75m²/南 北/天朗蓝湖树',
#  '3室2厅/115m²/南/碧桂园天玺',
#  '2室2厅/86.98m²/东 南/上东大道',
#  '1室1厅/52.75m²/西/阳光台365',
#  '3室2厅/122.91m²/南 北/三迪枫丹',
#  '3室2厅/150.75m²/东南/尊域',
#  '3室2厅/122m²/西南/银凯家园',
#  '3室2厅/115.77m²/南 北/山水岭秀',
#  '2室1厅/64m²/东北/美丽的院子',
#  '3室1厅/127m²/南 北/绿地曲江名城',
#  '2室2厅/45.06m²/南 北/罗马嘉园',
#  '4室2厅/171.22m²/南 北/万达天樾',
#  '2室2厅/78m²/南/铂廷',
#  '3室2厅/125.84m²/南 北/中铁缤纷南郡',
#  '3室2厅/136m²/南 北/中铁尚都城',
#  '3室1厅/93.25m²/南 北/华远海蓝城一期',
#  '1室0厅/38.38m²/北/莱安逸珲',
#  '2室1厅/85.87m²/南/铁建水岸雅苑',
#  '2室2厅/89.45m²/东 西/文化宫家属院']

# %%
[i.string for i in soup.select('.price-unit')]
# Out:
# ['16541元/平',
#  '14405元/平',
#  '15061元/平',
#  '11399元/平',
#  '13183元/平',
#  '14350元/平',
#  '17336元/平',
#  '15813元/平',
#  '12023元/平',
#  '27802元/平',
#  '22829元/平',
#  '17974元/平',
#  '15218元/平',
#  '13797元/平',
#  '13081元/平',
#  '13669元/平',
#  '16253元/平',
#  '11558元/平',
#  '15549元/平',
#  '15235元/平',
#  '14961元/平',
#  '19752元/平',
#  '24530元/平',
#  '14488元/平',
#  '18754元/平',
#  '12721元/平',
#  '16622元/平',
#  '18760元/平',
#  '11180元/平',
#  '10956元/平']

# %%
[i.string for i in soup.select('.house-tags')]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'VR房源',
#  '满两年',
#  'VR房源',
#  'VR房源',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '随时看房',
#  None,
#  None,
#  '随时看房',
#  'VR房源',
#  None,
#  None,
#  None,
#  None]

# %%
[i.text for i in soup.select('.house-text')]
# Out:
# ['万科金域东郡 舒适小两室  诚心出售2室1厅/70.01m²/南/万科金域东郡VR房源随时看房116万16541元/平',
#  '航天城小区一期三室 南北通透 产证满二 可按揭3室2厅/110.38m²/南 北/西安航天城A区VR房源随时看房新上159万14405元/平长安热门新上榜第1名',
#  '业主买的二手房满二，精装，明厨明卫3室1厅/99.6m²/南 北/华清学府城VR房源满两年随时看房150万15061元/平',
#  '水岸东方二期 毛坯三室 满三满二 南北通透3室1厅/149.14m²/南 北/水岸东方2期VR房源满五年随时看房170万11399元/平',
#  '北郊中轴线 地铁无缝对接 随时看房1室1厅/53.86m²/西/宫园壹号一期地铁VR房源71万13183元/平',
#  '金科天籁城余家寨地铁口万达广场旁边毛坯房。3室1厅/105.93m²/南/金科天籁城VR房源随时看房152万14350元/平',
#  '地铁口，纯新房，精装带家具家电，未曾入住过3室2厅/95.76m²/西南/融创天朗臻园VR房源随时看房166万17336元/平',
#  '此房为纯朝南两居，采光充足，房本在手，配套设齐全2室1厅/88.54m²/南/绿地曲江名城VR房源随时看房140万15813元/平',
#  '航天小区  业主自住  诚心出售  产权清晰 可 改两室1室1厅/46.33m²/西/航天小区地铁VR房源满五年随时看房56万12023元/平',
#  '枫林绿洲小高层南北通透全明三居室双旨标不临街有车位3室2厅/129.13m²/南 北/枫林绿洲VR房源359万27802元/平',
#  'I都会LOFT小户型，一手业主，學校明确，税费低1室1厅/35m²/南/逸翠园二期i都会满两年80万22829元/平',
#  '高新  3号线丈八北路站 满三满二 急售 小高层3室2厅/130.75m²/南 北/天朗蓝湖树VR房源235万17974元/平',
#  '房子通风，，户型方正，高楼层，不影响任何采光影响，3室2厅/115m²/南/碧桂园天玺VR房源175万15218元/平',
#  '满三满二，地铁口，精装修，诚心出售2室2厅/86.98m²/东 南/上东大道地铁VR房源满五年120万13797元/平',
# ...

# %%
[i.text for i in soup.select('.price-total')]
# Out:
# ['116万',
#  '159万',
#  '150万',
#  '170万',
#  '71万',
#  '152万',
#  '166万',
#  '140万',
#  '56万',
#  '359万',
#  '80万',
#  '235万',
#  '175万',
#  '120万',
#  '69万',
#  '168万',
#  '245万',
#  '141万',
#  '180万',
#  '98万',
#  '190万',
#  '89万',
#  '420万',
#  '113万',
#  '236万',
#  '173万',
#  '155万',
#  '72万',
#  '96万',
#  '98万']
