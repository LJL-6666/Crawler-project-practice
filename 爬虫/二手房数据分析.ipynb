# %%
import pandas as pd
fang=pd.read_csv('F:\\异类语言\\python\\ljlpython\\第七次作业\\西安二手房新.csv',encoding='gbk')
fang.head()
# Out:
#                               介绍   总价（元）   房屋信息房屋编码        发布时间          小区  \
# 0         两梯两户纯板风景御园可按揭地铁2号线公园旁边   260.0  649844308   2016/11/6      保亿风景御园
# 1          精装三居全配拎包入住婚房出售仅此一套60万    60.0  657563575  2016/11/14        世融嘉城
# 2        境商速递曲江公馆和园南湖边别墅品牌地产位置优越  1340.0  652092703   2016/11/8  曲江公馆和园（别墅）
# 3  科技六路万达旁兰亭坊二期5室2厅3卫256豪华装修,带私立   529.0  656304305  2016/11/13         兰亭坊
# 4       高山流水婚房出售拎包入住仅120万可按揭玛雅新推   120.0  657972394  2016/11/15    高山流水幸福快车
#
#    城区     地址                位置    年代  房龄  卧室数  厅数  生间    总面积  朝向  楼层    楼高  \
# 0  城北    经开区  城市运动公园南侧，张家堡转盘西侧  2000  17    3   2   2  188.0  南北  中层  共28层
# 1  城北    经开区      凤城四路与朱宏路十字东南  2012   5    2   2   1  102.0   南  中层  共32层
# 2  曲江   曲江新区          芙蓉西路雁塔一路  2015   2    5   2   3  452.0  南北  其他   共3层
# 3  高新  木塔寺公园            科技六路中段  2011   6    5   2   3  256.0  南北  高层  共16层
# 4  城北    经开区          太华北路848号  2010   7    4   2   2  139.0   南  低层  共30层
#
#      装修     单价     中介公司名称
# 0  简单装修  13829       亿德地产
# ...

# %%
d=fang.groupby('城区').mean()['单价']
d
# Out:
# 城区
# 其他     6915.666667
# 城东     6259.051724
# 城北     6631.572529
# 城南     7409.192593
# 城西     7328.797203
# 曲江    11606.513742
# 浐灞     7053.467890
# 长安     6827.712446
# 高新     9371.280788
# Name: 单价, dtype: float64

# %%
dt=fang.groupby([fang.城区,fang.装修]).mean()['单价']
dt
# Out:
# 城区  装修
# 其他  毛坯       3364.000000
#     简单装修     6727.500000
#     精装修      7749.000000
#     豪华装修     9177.000000
# 城东  中等装修     6285.227273
#     毛坯       5283.480769
#     简单装修     5853.392857
#     精装修      6617.464286
#     豪华装修     8804.750000
# 城北  中等装修     6512.589928
#     毛坯       5527.540856
#     简单装修     6147.490000
#     精装修      7501.061983
#     豪华装修    10003.926829
# 城南  中等装修     6769.472222
#     毛坯       7016.641026
#     简单装修     6888.727273
#     精装修      7638.129252
#     豪华装修     8866.600000
# 城西  中等装修     6318.520000
#     毛坯       6210.826087
#     简单装修     6194.416667
#     精装修      8534.750000
#     豪华装修    13019.500000
# 曲江  中等装修     8894.000000
#     毛坯      10174.425455
#     简单装修    12304.307692
#     精装修     11992.924812
#     豪华装修    19676.068182
# 浐灞  中等装修     8250.818182
#     毛坯       6707.862745
#     简单装修     6751.888889
#     精装修      6758.218750
#     豪华装修     9823.000000
# 长安  中等装修     5602.625000
#     毛坯       6126.586538
# ...

# %%
dt1=fang.groupby([fang.装修,fang.城区]).mean()['单价']
dt1
# Out:
# 装修    城区
# 中等装修  城东     6285.227273
#       城北     6512.589928
#       城南     6769.472222
#       城西     6318.520000
#       曲江     8894.000000
#       浐灞     8250.818182
#       长安     5602.625000
#       高新     8377.983871
# 毛坯    其他     3364.000000
#       城东     5283.480769
#       城北     5527.540856
#       城南     7016.641026
#       城西     6210.826087
#       曲江    10174.425455
#       浐灞     6707.862745
#       长安     6126.586538
#       高新     8928.961538
# 简单装修  其他     6727.500000
#       城东     5853.392857
#       城北     6147.490000
#       城南     6888.727273
#       城西     6194.416667
#       曲江    12304.307692
#       浐灞     6751.888889
#       长安     9479.833333
#       高新     8388.342105
# 精装修   其他     7749.000000
#       城东     6617.464286
#       城北     7501.061983
#       城南     7638.129252
#       城西     8534.750000
#       曲江    11992.924812
#       浐灞     6758.218750
#       长安     7644.500000
#       高新     9265.515432
# 豪华装修  其他     9177.000000
# ...
