# %%
import re
import requests
import json

# %%
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
url='https://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&ct=201326592&is=&fp=result&queryWord=%E4%B9%A0%E8%BF%91%E5%B9%B3&cl=2&lm=-1&ie=utf-8&oe=utf-8&adpicid=&st=-1&z=&ic=0&hd=&latest=&copyright=&word=%E4%B9%A0%E8%BF%91%E5%B9%B3&s=&se=&tab=&width=&height=&face=0&istype=2&qc=&nc=1&fr=&expermode=&force=&pn=30&rn=30&gsm=1e&1590050815131='
response=requests.get(url,headers=headers)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.text)
# Out:
# {"queryEnc":"%CF%B0%BD%FC%C6%BD","queryExt":"习近平","listNum":1044,"displayNum":1036718,"gsm":"3c","bdFmtDispNum":"约1,030,000","bdSearchTime":"","isNeedAsyncRequest":0,"bdIsClustered":"1","data":[{    "adType":"0",    "hasAspData":"0","thumbURL":"https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=1759991738,985627176&fm=26&gp=0.jpg","middleURL":"https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=1759991738,985627176&fm=26&gp=0.jpg",    "largeTnImageUrl":"",    "hasLarge" :0,    "hoverURL":"https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=1759991738,985627176&fm=26&gp=0.jpg",    "pageNum":30,    "objURL":"ippr_z2C$qAzdH3FAzdH3Fgjof_z&e3Bo56hj6vg_z&e3BvgAzdH3Fip4sAzdH3FutsjfAzdH3Fda8b-a9AzdH3F8aAzdH3Fda8ba98a8lamd0da8nbc08b_z&e3B3r2",    "fromURL":"ippr_z2C$qAzdH3FAzdH3Fgjof_z&e3Bo56hj6vg_z&e3BvgAzdH3Fndb9cAzdH3Fda8ba9AzdH3F88AzdH3F8ba988acn8cdmb0_z&e3Bfip4s",    "fromURLHost":"news.workercn.cn",    "currentIndex":"",    "width":450,    "height":290,    "type":"jpg
# ...

# %%
data=json.loads(response.text)
len(data['data'])
# Out:
# 31

# %%
data['data']
# Out:
# [{'adType': '0',
#   'hasAspData': '0',
#   'thumbURL': 'https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=1759991738,985627176&fm=26&gp=0.jpg',
#   'middleURL': 'https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=1759991738,985627176&fm=26&gp=0.jpg',
#   'largeTnImageUrl': '',
#   'hasLarge': 0,
#   'hoverURL': 'https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=1759991738,985627176&fm=26&gp=0.jpg',
#   'pageNum': 30,
#   'objURL': 'ippr_z2C$qAzdH3FAzdH3Fgjof_z&e3Bo56hj6vg_z&e3BvgAzdH3Fip4sAzdH3FutsjfAzdH3Fda8b-a9AzdH3F8aAzdH3Fda8ba98a8lamd0da8nbc08b_z&e3B3r2',
#   'fromURL': 'ippr_z2C$qAzdH3FAzdH3Fgjof_z&e3Bo56hj6vg_z&e3BvgAzdH3Fndb9cAzdH3Fda8ba9AzdH3F88AzdH3F8ba988acn8cdmb0_z&e3Bfip4s',
#   'fromURLHost': 'news.workercn.cn',
#   'currentIndex': '',
#   'width': 450,
#   'height': 290,
#   'type': 'jpg',
#   'is_gif': 0,
#   'strategyAssessment': '3185060450_32_0_0',
#   'filesize': '',
#   'bdSrcType': '0',
#   'di': '78980',
#   'pi': '0',
#   'is': '0,0',
# ...

# %%
url_p=[]

# %%
for i in range(0,len(data['data'])-1):
    url_p.append(data['data'][i]['thumbURL'])

# %%
url_p
# Out:
# ['https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=1759991738,985627176&fm=26&gp=0.jpg',
#  'https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=3916172680,3035820500&fm=26&gp=0.jpg',
#  'https://ss0.bdstatic.com/70cFvHSh_Q1YnxGkpoWK1HF6hhy/it/u=2888834387,1572461321&fm=26&gp=0.jpg',
#  'https://ss3.bdstatic.com/70cFv8Sh_Q1YnxGkpoWK1HF6hhy/it/u=219368380,1808173145&fm=26&gp=0.jpg',
#  'https://ss2.bdstatic.com/70cFvnSh_Q1YnxGkpoWK1HF6hhy/it/u=3829526114,631033180&fm=26&gp=0.jpg',
#  'https://ss0.bdstatic.com/70cFuHSh_Q1YnxGkpoWK1HF6hhy/it/u=1848399700,2922999358&fm=26&gp=0.jpg',
#  'https://ss0.bdstatic.com/70cFvHSh_Q1YnxGkpoWK1HF6hhy/it/u=1589060476,2692610468&fm=26&gp=0.jpg',
#  'https://ss1.bdstatic.com/70cFuXSh_Q1YnxGkpoWK1HF6hhy/it/u=3394826450,3354249655&fm=26&gp=0.jpg',
#  'https://ss1.bdstatic.com/70cFvXSh_Q1YnxGkpoWK1HF6hhy/it/u=1474274229,4087342736&fm=26&gp=0.jpg',
# ...

# %%
for i, pic_url in enumerate(url_p):
    pic_t = requests.get(pic_url,timeout=15)
    string = 'G:/CDO/数据存储和获取/习大大图片爬取/'+'第'+str(i+1)+ '张.jpg'
    with open(string, 'wb') as f:
        f.write(pic_t.content)
